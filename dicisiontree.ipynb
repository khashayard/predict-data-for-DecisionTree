# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
data
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
go = {'NO':1,'YES':0}
nat = {'UK':1, 'USA':2,'N':3}

# %%
data['Go'] = data['Go'].map(go)
data['Nationality']=data['Nationality'].map(nat)
data
# Out:
#     Age  Experience  Rank  Nationality  Go
# 0    36          10     9            1   1
# 1    42          12     4            2   1
# 2    23           4     6            3   1
# 3    52           4     4            2   1
# 4    43          21     8            2   0
# 5    44          14     5            1   1
# 6    66           3     7            3   0
# 7    35          14     9            1   0
# 8    52          13     7            3   0
# 9    35           5     9            3   0
# 10   24           3     5            2   1
# 11   18           3     7            1   0
# 12   45           9     9            1   0

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
d = ['Age','Experience','Rank','Nationality']
X = data[d]
y = data['Go']
# Out:
#     Age  Experience  Rank  Nationality
# 0    36          10     9            1
# 1    42          12     4            2
# 2    23           4     6            3
# 3    52           4     4            2
# 4    43          21     8            2
# 5    44          14     5            1
# 6    66           3     7            3
# 7    35          14     9            1
# 8    52          13     7            3
# 9    35           5     9            3
# 10   24           3     5            2
# 11   18           3     7            1
# 12   45           9     9            1

# %%
dtree = DecisionTreeClassifier()
dtree =dtree.fit(X , y)
tree.plot_tree(dtree,feature_names=d)
# Out:
# [Text(0.2857142857142857, 0.9, 'Rank <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.14285714285714285, 0.7, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.42857142857142855, 0.7, 'Rank <= 8.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.2857142857142857, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5714285714285714, 0.5, 'Age <= 35.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7142857142857143, 0.3, 'Age <= 40.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5714285714285714, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8571428571428571, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]
